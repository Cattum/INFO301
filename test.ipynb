# %% [markdown]
# <a href="https://colab.research.google.com/github/Cattum/INFO301/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# Simulated data for a performance landscape
X, Y = np.meshgrid(np.linspace(-5, 5, 50), np.linspace(-5, 5, 50))
Z = np.sin(np.sqrt(X**2 + Y**2))

# Creating a 3D contour plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.contour3D(X, Y, Z, 50, cmap='viridis')
ax.set_title("3D Contour of Model Performance")
ax.set_xlabel("Hyperparameter 1")
ax.set_ylabel("Hyperparameter 2")
ax.set_zlabel("Performance")
plt.show()
